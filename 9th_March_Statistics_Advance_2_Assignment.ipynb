# %% [markdown]
# Q1: What are the Probability Mass Function (PMF) and Probability Density Function (PDF)? Explain with
# an example.

# %% [markdown]
# Answer:-
#
# The Probability Mass Function (PMF) and the Probability Density Function (PDF) are concepts used in probability theory to describe the distribution of a discrete random variable and a continuous random variable, respectively.
#
# Probability Mass Function (PMF)
# The PMF applies to discrete random variables. It gives the probability that a discrete random variable is exactly equal to some value. Essentially, it describes the probability distribution of a discrete random variable. The PMF
# 𝑃(𝑋=𝑥)provides the probabilities for each possible value that a discrete random variable can take.
#
# Example: Consider a fair six-sided die. The PMF of rolling the die can be represented as:
# 𝑃
# (
# 𝑋
# =
# 1
# )
# =
# 1
# 6
#
# 𝑃
# (
# 𝑋
# =
# 2
# )
# =
# 1
# 6
#
# 𝑃
# (
# 𝑋
# =
# 3
# )
# =
# 1
# 6
#
# 𝑃
# (
# 𝑋
# =
# 4
# )
# =
# 1
# 6
#
# 𝑃
# (
# 𝑋
# =
# 5
# )
# =
# 1
# 6
#
# 𝑃
# (
# 𝑋
# =
# 6
# )
# =
# 1
# 6
#
# Here,
# 𝑋
#  is the discrete random variable representing the outcome of the die roll.
#
# Probability Density Function (PDF)
#
# The PDF applies to continuous random variables. It describes the probability distribution of a continuous random variable. Unlike the PMF, the PDF does not give probabilities directly. Instead, the area under the curve of the PDF over a specific interval gives the probability that the random variable falls within that interval. The PDF is denoted as
# 𝑓
# (
# 𝑥
# )
# .
#
# Example: Consider the height of adult men in a certain population, which is normally distributed with a mean
# 𝜇
#  and standard deviation
# 𝜎
# . The PDF of a normal distribution can be represented as:
#
# \[ f(x) = \frac{1}{\sigma \sqrt{2\pi}} \exp\left(-\frac{(x - \mu)2}{2\sigma2}\right) \]
#
# Here,
# 𝑓
# (
# 𝑥
# )
#  gives the density at any given height
# 𝑥
# , and the total area under the curve from
# −
# ∞
#  to
# +
# ∞
#  is 1, which represents the total probability.
#
# In summary:
#
# PMF is used for discrete random variables and gives the probability that the variable takes on a specific value.
#
# PDF is used for continuous random variables and describes the probability distribution through a density function. The area under the curve of the PDF over an interval provides the probability for that interval.

# %% [markdown]
# Q2: What is Cumulative Density Function (CDF)? Explain with an example. Why CDF is used?

# %% [markdown]
# Answer:-
#
# The Cumulative Distribution Function (CDF) is a function that describes the probability that a random variable takes on a value less than or equal to a certain point. It provides a way to understand the distribution of probabilities over a range of values for both discrete and continuous random variables.
#
# Example of CDF
# Let's consider an example with a continuous random variable: the height of adults in a certain population. Suppose the heights are normally distributed with a mean (
# 𝜇
# ) of 170 cm and a standard deviation (
# 𝜎
# ) of 10 cm.
#
# The CDF for this normal distribution, denoted as
# 𝐹
# (
# 𝑥
# )
# , is the probability that a randomly chosen adult's height is less than or equal to
# 𝑥
#  cm. Mathematically, it can be expressed as:
#
# 𝐹
# (
# 𝑥
# )
# =
# 𝑃
# (
# 𝑋
# ≤
# 𝑥
# )
#
# For instance, if we want to find the probability that an adult's height is less than or equal to 180 cm, we would use the CDF of the normal distribution. Using the CDF formula for a normal distribution, we would get a specific probability value.
#
# The Uses of CDF are as follows:-
#
# 1.Comprehensive Probability Information: The CDF provides a cumulative probability for a range of values, not just specific points. This makes it easier to understand how probabilities accumulate across the distribution.
#
# 2.Comparison Tool: It allows for easy comparison of different distributions and helps in identifying the central tendency, spread, and shape of the data.
#
# 3.Applications: CDFs are widely used in statistical analyses, risk assessments, and reliability engineering. They help in making decisions based on the probability of certain outcomes occurring within a specified range.
#
# 4.Critical Values and Confidence Intervals: CDFs are essential for determining critical values and constructing confidence intervals in hypothesis testing.

# %% [markdown]
# Q3: What are some examples of situations where the normal distribution might be used as a model?
# Explain how the parameters of the normal distribution relate to the shape of the distribution.

# %% [markdown]
# Answer :
#
# The normal distribution, also known as the Gaussian distribution, is a commonly used probability distribution that is used to model a wide variety of real-world phenomena. Here are some examples of situations where the normal distribution might be used as a model:
#
# 1.Height of a population: The normal distribution can be used to model the heights of a population. In this case, the mean and standard deviation of the distribution would reflect the average height and the degree of variation in height, respectively.
#
# 2.IQ scores: IQ scores are often modeled using the normal distribution. In this case, the mean and standard deviation would reflect the average IQ score and the degree of variation in IQ scores, respectively.
#
# 3.Measurement errors: The normal distribution can be used to model measurement errors in scientific experiments. The mean of the distribution would be zero (since the errors are assumed to be random and unbiased), and the standard deviation would reflect the degree of variability in the errors.
#
# The normal distribution is characterized by two parameters: the mean (μ) and the standard deviation (σ). The mean determines the location of the peak of the distribution, and the standard deviation determines the width of the distribution. Specifically, the greater the standard deviation, the wider the distribution will be.
#
# The normal distribution is a bell-shaped curve that is symmetrical around the mean. About 68% of the data falls within one standard deviation of the mean, about 95% falls within two standard deviations of the mean, and about 99.7% falls within three standard deviations of the mean. These properties make the normal distribution a convenient model for a wide variety of real-world phenomena.

# %% [markdown]
# Q4: Explain the importance of Normal Distribution. Give a few real-life examples of Normal
# Distribution.

# %% [markdown]
# Answer :-
#
# Normal distribution, also known as Gaussian distribution, is a probability distribution that is widely used in statistics, data analysis, and modeling. It is an important concept in statistics because many natural phenomena can be modeled using normal distributions.
#
# The importance of normal distribution lies in its usefulness in approximating many real-world processes, allowing us to make predictions, estimate probabilities, and analyze data. The following are a few examples of real-life phenomena that can be modeled using normal distribution:
#
# 1.Body temperature: The body temperature of a healthy human is normally distributed with an average of 98.6 degrees Fahrenheit and a standard deviation of about 0.7 degrees Farenheit.
#
# 2.Reaction time: The reaction times of individuals can be modeled using normal distribution. Most people have an average reaction time, with fewer people having very fast or very slow reaction times.
#
# 3.Annual rainfall: The amount of rainfall in a particular area over a year can be modeled using normal distribution, with most years having average rainfall and fewer years experiencing extreme droughts or floods.
#
# 4.Hospital stays: The length of time a patient stays in a hospital can be modeled using normal distribution, with most patients staying for an average length of time and fewer patients having very short or very long stays.
#
# 5.Income distribution: In many countries, income distribution can be modeled using a log-normal distribution, which is a variant of the normal distribution. This means that most people have an average income, with fewer people having very low or very high incomes.
#
# 6.Test-retest reliability: In psychology, the test-retest reliability of psychological tests can be modeled using normal distribution. This measures the consistency of test scores when the same test is administered to the same individual on different occasions.
#
# These are just a few examples of how normal distribution can be used to model a wide variety of real-life phenomena.

# %% [markdown]
# Q5: What is Bernaulli Distribution? Give an Example. What is the difference between Bernoulli
# Distribution and Binomial Distribution?

# %% [markdown]
# Answer:-
#
# Bernoulli Distribution
# The Bernoulli distribution is the simplest discrete probability distribution. It describes a random experiment with only two possible outcomes: success (with probability
# 𝑝
# ) and failure (with probability
# 1
# −
# 𝑝
# ). A random variable following this distribution,
# 𝑋
# , takes the value 1 (success) with probability
# 𝑝
#  and the value 0 (failure) with probability
# 1
# −
# 𝑝
# .
#
# Example: Consider flipping a fair coin. The outcome can either be heads (success) or tails (failure). If
# 𝑝
# =
# 0.5
#  for heads, the Bernoulli distribution for this experiment would be:
#
# 𝑃
# (
# 𝑋
# =
# 1
# )
# =
# 0.5
#  (heads)
#
# 𝑃
# (
# 𝑋
# =
# 0
# )
# =
# 0.5
#  (tails)
#
# Difference Between Bernoulli Distribution and Binomial Distribution
# Both Bernoulli and binomial distributions deal with binary outcomes (success/failure), but there are key differences:
#
# 1.Number of Trials:
#
# Bernoulli Distribution: Deals with a single trial.
#
# Binomial Distribution: Deals with multiple trials (n trials).
#
# 2.Probability Distribution:
#
# Bernoulli Distribution: The probability mass function is
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# 𝑝
# 𝑥
# (
# 1
# −
# 𝑝
# )
# 1
# −
# 𝑥
#  for
# 𝑥
# =
# 0
#  or
# 1
# .
#
# Binomial Distribution: The probability mass function is
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# (
# 𝑛
# 𝑘
# )
# 𝑝
# 𝑘
# (
# 1
# −
# 𝑝
# )
# 𝑛
# −
# 𝑘
#  where
# 𝑛
#  is the number of trials,
# 𝑘
#  is the number of successes, and
# 𝑝
#  is the probability of success on a single trial.
#
# 3.Parameters:
#
# Bernoulli Distribution: Has only one parameter
# 𝑝
#  (the probability of success).
#
# Binomial Distribution: Has two parameters
# 𝑛
#  (number of trials) and
# 𝑝
#  (probability of success per trial).
#
# Example Comparing the Two:
#
# Bernoulli Example: Flipping a coin once.
#
# Binomial Example: Flipping a coin 10 times and counting the number of heads.

# %% [markdown]
# Q6. Consider a dataset with a mean of 50 and a standard deviation of 10. If we assume that the dataset
# is normally distributed, what is the probability that a randomly selected observation will be greater
# than 60? Use the appropriate formula and show your calculations.

# %% [markdown]
# Answer:-
#
# To find the probability that a randomly selected observation from a normally distributed dataset with a mean of 50 and a standard deviation of 10 is greater than 60, we can use the standard normal distribution (z-distribution).
#
# First, we need to convert the value 60 to a z-score using the formula:
#
# 𝑧
# =
# (
# 𝑋
# −
# 𝜇
# )
# 𝜎
#
# where:
#
# 𝑋
#  is the value we are interested in (60 in this case),
#
# 𝜇
#  is the mean (50),
#
# 𝜎
#  is the standard deviation (10).
#
# So, let's calculate the z-score:
#
# 𝑧
# =
# (
# 60
# −
# 50
# )/
# 10
# =
# 10
# /10
# =
# 1
#
# Now, we need to find the probability that
# 𝑍
#  (the standard normal variable) is greater than 1. We can use the cumulative distribution function (CDF) of the standard normal distribution, which gives us the probability that
# 𝑍
#  is less than or equal to a certain value.
#
# Using standard normal distribution tables or a calculator, the CDF value for
# 𝑍
# =
# 1
#  is approximately 0.8413. This means that the probability that
# 𝑍
#  is less than or equal to 1 is 0.8413.
#
# To find the probability that
# 𝑍
#  is greater than 1, we subtract this value from 1:
#
# 𝑃(𝑍 >
# 1
# )
# =
# 1
# −
# 𝑃
# (
# 𝑍
# ≤
# 1
# )
# =
# 1
# −
# 0.8413
# =
# 0.1587
#
# Therefore, the probability that a randomly selected observation will be greater than 60 is approximately 0.1587, or 15.87%.
#
# In summary:
#
# Mean (μ): 50
#
# Standard Deviation (σ): 10
#
# Z-score for X = 60: 1
#
# Probability (P(X > 60)): 0.1587 (15.87%)

# %% [markdown]
# Q7: Explain uniform Distribution with an example.

# %% [markdown]
# Answer:-
#
# Uniform distribution is a probability distribution where every possible outcome has an equal chance of occurring. This means that the values of a random variable are spread evenly over a given interval or range.
#
# A classic example of a uniform distribution is the roll of a fair die. The die has six faces, each labeled with a number from 1 to 6, and all the faces are equally likely to come up when the die is rolled. Therefore, the probability of each outcome is 1/6, and this distribution is called a discrete uniform distribution.
#
# Lottery or raffle draws - If a lottery or raffle is conducted fairly, where each ticket has an equal chance of being drawn, the distribution of winning ticket numbers follows a discrete uniform distribution.

# %% [markdown]
# Q8: What is the z score? State the importance of the z score.

# %% [markdown]
# Answer:-
#
# A z-score (also known as a standard score) measures how many standard deviations a data point is from the mean of a distribution. It is a way of standardizing scores on the same scale, so comparisons can be made. The formula for calculating a z-score is:
#
# 𝑧
# =
# (
# 𝑋
# −
# 𝜇
# )
# 𝜎
# where:
#
# 𝑋
#  is the value of the data point,
#
# 𝜇
#  is the mean of the dataset,
#
# 𝜎
#  is the standard deviation of the dataset.
#
# Importance of the Z Score
#
# 1.Standardization: Z-scores standardize different data points, making it possible to compare scores from different datasets or distributions. This is particularly useful when combining data from different sources.
#
# 2.Identifying Outliers: By converting data points into z-scores, it is easier to identify outliers. Data points with z-scores above 3 or below -3 are typically considered outliers.
#
# 3.Probability Calculations: Z-scores are used in probability calculations for normal distributions. They help in finding the probability that a score is above, below, or between certain values by referencing standard normal distribution tables.
#
# 4.Hypothesis Testing: Z-scores are critical in hypothesis testing, particularly in z-tests. They help determine whether to accept or reject a hypothesis by comparing the z-score to critical values.
#
# 5.Quality Control: In manufacturing and quality control processes, z-scores are used to monitor and control variations in production processes, ensuring consistency and quality.
#
# Example
#
# Consider a dataset of test scores with a mean (μ) of 70 and a standard deviation (σ) of 10. If a student scored 85 on the test, we can calculate the z-score:
#
# 𝑧
# =
# (
# 85
# −
# 70
# )/
# 10
# =
# 15/
# 10
# =
# 1.5
#
# This means the student's score is 1.5 standard deviations above the mean

# %% [markdown]
# Q9: What is Central Limit Theorem? State the significance of the Central Limit Theorem.

# %% [markdown]
# Answer:-
#
# The central limit theorem (CLT) is a theorem in probability theory that states that, given certain conditions, the arithmetic mean of a sufficiently large number of iterates of independent random variables, each with a well-defined expected value and well-defined variance, will be approximately normally distributed, regardless of the underlying distribution.
#
# The CLT is a fundamental theorem in statistics and has wide-ranging applications. It is used in hypothesis testing, confidence interval estimation, and regression analysis.
#
# The CLT is based on the idea that the average of a large number of random variables will be closer to the population mean than any individual random variable. This is because the average of a large number of random variables will tend to cancel out the effects of any outliers or extreme values.
#
# The CLT also states that the standard deviation of the average of a large number of random variables will be smaller than the standard deviation of any individual random variable. This is because the average of a large number of random variables will tend to smooth out the fluctuations in the individual random variables.
#
# The CLT is a powerful tool that can be used to make inferences about populations based on samples. For example, if you want to know the average height of all people in the United States, you could take a random sample of people and calculate the average height of the sample. If the sample is large enough, the CLT tells you that the average height of the sample will be approximately normally distributed. This means that you can use a z-table to find the probability that the average height of the sample is within a certain range of the population mean.
#
# The CLT is also used in many other areas of statistics, such as hypothesis testing, confidence intervals, and regression analysis.
#
# Here are some of the significance of the Central Limit Theorem:
#
# It allows us to make inferences about populations based on samples. It can be used to calculate probabilities of events occurring. It can be used to estimate population parameters. It is used in many different areas of statistics, such as hypothesis testing, confidence intervals, and regression analysis. The CLT is a powerful tool that can be used to make sense of data. It is essential for understanding many statistical concepts and techniques.
#
# Here are some examples of how the CLT is used in practice:
#
# In hypothesis testing, the CLT is used to calculate the p-value of a test statistic. The p-value is the probability of obtaining a test statistic at least as extreme as the one that was observed, assuming that the null hypothesis is true. In confidence interval estimation, the CLT is used to calculate the confidence interval for a population parameter. The confidence interval is a range of values that is likely to contain the population parameter. In regression analysis, the CLT is used to calculate the standard errors of the regression coefficients. The standard errors of the regression coefficients are used to test the significance of the coefficients and to construct confidence intervals for the predicted values. The CLT is a powerful tool that can be used to make inferences about populations based on samples. It is essential for understanding many statistical concepts and techniques.

# %% [markdown]
# Q10: State the assumptions of the Central Limit Theorem.

# %% [markdown]
# Answer:-
#
# The Central Limit Theorem (CLT) has some assumptions that need to be satisfied for it to hold. The assumptions of the Central Limit Theorem are as follows:-
#
# 1.Independence - The samples must be independent of each other. In other words, the value of one sample should not depend on the value of another sample.
#
# 2.Sample size - The sample size should be large enough. Generally, a sample size of at least 30 is considered to be large enough for the Central Limit Theorem to hold.
#
# 3.Random sampling - The samples should be selected randomly from the population.
#
# 4.Finite population or replacement - The population should be finite or the sampling should be done with replacement. If the population is infinite and the sampling is done without replacement, then the Central Limit Theorem may not hold.
#
# 5.Finite mean and variance - The population should have a finite mean and variance. If the mean or variance is infinite, then the Central Limit Theorem may not hold.
#
# If these assumptions are satisfied, then the Central Limit Theorem can be applied to the data to make inferences about the population mean or other parameters. It is important to note that violating any of these assumptions can lead to incorrect results, so it is essential to check the validity of the assumptions before applying the Central Limit Theorem.
